# %% [markdown]
# <a href="https://colab.research.google.com/github/dammy4real75/data-learnig/blob/main/Sat%2019/11/2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/Avado Training/Food_Sale_Full_Data.csv")
df
# Out:
#       OrderDate Region         City  Category         Product  Quantity  \
# 0      1/1/2020   East       Boston      Bars          Carrot        33
# 1      1/4/2020   East       Boston  Crackers     Whole Wheat        87
# 2      1/7/2020   West  Los Angeles   Cookies  Chocolate Chip        58
# 3     1/10/2020   East     New York   Cookies  Chocolate Chip        82
# 4     1/13/2020   East       Boston   Cookies       Arrowroot        38
# ..          ...    ...          ...       ...             ...       ...
# 239  12/18/2021   East       Boston   Cookies       Arrowroot        34
# 240  12/21/2021   East       Boston   Cookies  Chocolate Chip       245
# 241  12/24/2021   East       Boston  Crackers     Whole Wheat        30
# 242  12/27/2021   West  Los Angeles      Bars            Bran        30
# 243  12/30/2021   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 0         1.77       58.41
# 1         3.49      303.63
# ...

# %%
df.head()
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot        33
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat        87
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip        58
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip        82
# 4  1/13/2020   East       Boston   Cookies       Arrowroot        38
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84

# %%
df.head(10)
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot        33
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat        87
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip        58
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip        82
# 4  1/13/2020   East       Boston   Cookies       Arrowroot        38
# 5  1/16/2020   East       Boston      Bars          Carrot        54
# 6  1/19/2020   East       Boston  Crackers     Whole Wheat       149
# 7  1/22/2020   West  Los Angeles      Bars          Carrot        51
# 8  1/25/2020   East     New York      Bars          Carrot       100
# 9  1/28/2020   East     New York    Snacks    Potato Chips        28
#
#    UnitPrice  TotalPrice
# 0       1.77       58.41
# 1       3.49      303.63
# 2       1.87      108.46
# 3       1.87      153.34
# 4       2.18       82.84
# 5       1.77       95.58
# ...

# %%
df.tail()
# Out:
#       OrderDate Region         City  Category         Product  Quantity  \
# 239  12/18/2021   East       Boston   Cookies       Arrowroot        34
# 240  12/21/2021   East       Boston   Cookies  Chocolate Chip       245
# 241  12/24/2021   East       Boston  Crackers     Whole Wheat        30
# 242  12/27/2021   West  Los Angeles      Bars            Bran        30
# 243  12/30/2021   West  Los Angeles   Cookies  Oatmeal Raisin        44
#
#      UnitPrice  TotalPrice
# 239       2.18       74.12
# 240       1.87      458.15
# 241       3.49      104.70
# 242       1.87       56.10
# 243       2.84      124.96

# %%
df.tail(20)
# Out:
#       OrderDate Region         City  Category         Product  Quantity  \
# 224   11/3/2021   West    San Diego   Cookies  Chocolate Chip        24
# 225   11/6/2021   East       Boston      Bars            Bran        83
# 226   11/9/2021   East       Boston   Cookies  Oatmeal Raisin       124
# 227  11/12/2021   West  Los Angeles      Bars          Carrot       137
# 228  11/15/2021   East     New York   Cookies       Arrowroot       146
# 229  11/18/2021   East     New York   Cookies  Chocolate Chip        34
# 230  11/21/2021   West    San Diego      Bars          Carrot        20
# 231  11/24/2021   East       Boston   Cookies       Arrowroot       139
# 232  11/27/2021   East       Boston   Cookies  Chocolate Chip       211
# 233  11/30/2021   East       Boston  Crackers     Whole Wheat        20
# 234   12/3/2021   West  Los Angeles      Bars            Bran        42
# 235   12/6/2021   West  Los Angeles   Cookies  Oatmeal Raisin       100
# ...

# %%
df["OrderDate"]
# Out:
# 0        1/1/2020
# 1        1/4/2020
# 2        1/7/2020
# 3       1/10/2020
# 4       1/13/2020
#           ...
# 239    12/18/2021
# 240    12/21/2021
# 241    12/24/2021
# 242    12/27/2021
# 243    12/30/2021
# Name: OrderDate, Length: 244, dtype: object

# %%
df[["Category","City","OrderDate"]]
# Out:
#      Category         City   OrderDate
# 0        Bars       Boston    1/1/2020
# 1    Crackers       Boston    1/4/2020
# 2     Cookies  Los Angeles    1/7/2020
# 3     Cookies     New York   1/10/2020
# 4     Cookies       Boston   1/13/2020
# ..        ...          ...         ...
# 239   Cookies       Boston  12/18/2021
# 240   Cookies       Boston  12/21/2021
# 241  Crackers       Boston  12/24/2021
# 242      Bars  Los Angeles  12/27/2021
# 243   Cookies  Los Angeles  12/30/2021
#
# [244 rows x 3 columns]

# %%
df.loc[0,"OrderDate"]
# Out:
# '1/1/2020'

# %%
df.describe()
# Out:
#          Quantity   UnitPrice  TotalPrice
# count  244.000000  244.000000  244.000000
# mean    63.286885    2.200820  136.580246
# std     47.112505    0.600169  108.354231
# min     20.000000    1.350000   33.600000
# 25%     31.000000    1.770000   72.570000
# 50%     47.000000    1.870000  102.755000
# 75%     80.000000    2.840000  159.300000
# max    306.000000    3.490000  817.920000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   244 non-null    object
#  1   Region      244 non-null    object
#  2   City        244 non-null    object
#  3   Category    244 non-null    object
#  4   Product     244 non-null    object
#  5   Quantity    244 non-null    int64
#  6   UnitPrice   244 non-null    float64
#  7   TotalPrice  244 non-null    float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 15.4+ KB

# %%
df.loc[0,"OrderDate"]
# Out:
# '1/1/2020'

# %%
df.loc[0,"OrderDate"].day_name()
# Out:
# 'Wednesday'

# %%
df["OrderDate"]=pd.to_datetime(df["OrderDate"])

# %%
#alternative
df["OrderDate"]=pd.to_datetime(df["OrderDate"],format="%m/%d/%Y")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#matplotlib
plt.barh(df["Region"],df["TotalPrice"])
plt.show()

# %%
#seaborn
sns.barplot(df["TotalPrice"],df["Region"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#creating dataframe
Region_price=df.groupby("Region")["TotalPrice"].sum().to_frame().reset_index()
Region_price
# Out:
#   Region  TotalPrice
# 0   East    21524.36
# 1   West    11801.22

# %%
plt.barh(Region_price["Region"],Region_price["TotalPrice"])
plt.show()

# %%
sns.barplot(Region_price["TotalPrice"],Region_price["Region"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
#titles and labels
#Matplotlib
plt.barh(Region_price["Region"],Region_price["TotalPrice"])
plt.title("Total Revenue per region")
plt.xlabel("Total Price")
plt.ylabel("Region")
plt.show()

# %%
#titles and labels
#Matplotlib
plt.barh(Region_price["Region"],Region_price["TotalPrice"],color=["lightblue","slategrey"])
plt.title("Total Revenue per region")
plt.xlabel("Total Price")
plt.ylabel("Region")
plt.grid(color="whitesmoke",linestyle="--",linewidth=0.8)
plt.show()

# %%
sns.barplot(Region_price["TotalPrice"],Region_price["Region"],palette="Blues")
plt.title("Total Revenue per region")
plt.xlabel("Total Price")
plt.ylabel("Region")
plt.grid(color="grey",linestyle="-",linewidth=0.8)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# # Grouped Column Chart

# %%
import numpy as np

# %%
df_pivot=pd.pivot_table(df,values="TotalPrice",index="Category",columns="City",aggfunc=np.mean)
df_pivot
# Out:
# City          Boston  Los Angeles    New York   San Diego
# Category
# Bars      114.482414   120.265417  116.738846   86.266667
# Cookies   202.546875   183.842273  191.000000  130.756842
# Crackers  149.043529    73.290000   98.418000   83.760000
# Snacks     93.030000    87.120000   58.836667   56.000000

# %%
#matplotlib
df_pivot=pd.pivot_table(df,values="TotalPrice",index="Category",columns="City",aggfunc=np.mean)
groupchart=df_pivot.plot(kind="bar",alpha=0.9,color=["lightblue","teal","mediumpurple","red"])
plt.title("Total sales per city")
plt.ylabel("Total Price")
plt.xlabel(None)
df_pivot
# Out:
# City          Boston  Los Angeles    New York   San Diego
# Category
# Bars      114.482414   120.265417  116.738846   86.266667
# Cookies   202.546875   183.842273  191.000000  130.756842
# Crackers  149.043529    73.290000   98.418000   83.760000
# Snacks     93.030000    87.120000   58.836667   56.000000

# %%
#seaborn
sns.barplot(x="Category",y="TotalPrice",hue="City",data=df,palette="Blues")
plt.title("Total sales per city")
plt.ylabel("Total Price")
plt.xlabel(None)
df_pivot
# Out:
# City          Boston  Los Angeles    New York   San Diego
# Category
# Bars      114.482414   120.265417  116.738846   86.266667
# Cookies   202.546875   183.842273  191.000000  130.756842
# Crackers  149.043529    73.290000   98.418000   83.760000
# Snacks     93.030000    87.120000   58.836667   56.000000

# %% [markdown]
# ## Pie Chart

# %%
City_price=df.groupby("City")["TotalPrice"].sum().to_frame().reset_index()
City_price
# Out:
#           City  TotalPrice
# 0       Boston    13265.53
# 1  Los Angeles     7687.32
# 2     New York     8258.83
# 3    San Diego     4113.90

# %%
total_price=City_price["TotalPrice"]
city_data=City_price["City"]
palette_colour=sns.color_palette("Blues")
plt.pie(total_price,labels=city_data,colors=palette_colour,autopct="%0.0f%%")
plt.title("Total Sales per City")
plt.xlabel(None)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Box plot

# %%
columns=[df["Quantity"],df["TotalPrice"]]
plt.boxplot(columns)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6d42731f50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f6d42792710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6d427315d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f6d426f5f10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6d426f5250>,
# ...
#  'means': []}

# %%
columns=[df["Quantity"],df["TotalPrice"]]
plt.boxplot(columns,labels=("Quantity","TT Price"))
plt.show()

# %%
columns=[df["Quantity"],df["TotalPrice"]]
plt.boxplot(columns,labels=("Quantity","TT Price"))
plt.show()
#
df["TotalPrice"].max()
df["Quantity"].max()
# Out:
# 306

# %%
#seaborn
sns.boxplot(data=[df["Quantity"],df["TotalPrice"]])
plt.show()

# %% [markdown]
# ## Line Chart

# %%
Data = {'Year': [1990,1995,2000,2005,2010,2015,2020],
        'Population': [57,58,59,60,63,65,68]
       }

# %%
#creating data frame
df1=pd.DataFrame(Data,columns=["Year","Population"])
df1
# Out:
#    Year  Population
# 0  1990          57
# 1  1995          58
# 2  2000          59
# 3  2005          60
# 4  2010          63
# 5  2015          65
# 6  2020          68

# %%
#matplotlib
df1=pd.DataFrame(Data,columns=["Year","Population"])
plt.plot(df1["Year"],df1['Population'],color="slategrey",marker="o")

# %%
df1=pd.DataFrame(Data,columns=["Year","Population"])
plt.plot(df1["Year"],df1['Population'],color="slategrey",marker="o")
plt.title("Population vs Year",fontsize=16)
plt.xlabel("Year",fontsize=12)
plt.ylabel("Population in millions",fontsize=12)
plt.grid(color="grey",linestyle="--",linewidth=0.7)
plt.xticks(rotation=45)
plt.show()

# %%
#matplotlib df data
df_date=df.groupby("OrderDate")["TotalPrice"].sum().to_frame().reset_index()
df_date
# Out:
#      OrderDate  TotalPrice
# 0   2020-01-01       58.41
# 1   2020-01-04      303.63
# 2   2020-01-07      108.46
# 3   2020-01-10      153.34
# 4   2020-01-13       82.84
# ..         ...         ...
# 239 2021-12-18       74.12
# 240 2021-12-21      458.15
# 241 2021-12-24      104.70
# 242 2021-12-27       56.10
# 243 2021-12-30      124.96
#
# [244 rows x 2 columns]

# %%
df_date=df.groupby("OrderDate")["TotalPrice"].sum().to_frame().reset_index()
plt.plot(df_date['OrderDate'],df_date['TotalPrice'])
plt.title("TotalPrice vs OrderDate",fontsize=16)
plt.xlabel("OrderDate",fontsize=12)
plt.ylabel("TotalPrice",fontsize=12)
plt.grid(color="grey",linestyle="--",linewidth=0.7)
plt.xticks(rotation=45)
plt.show()

# %%
#seaborn
df1
# Out:
#    Year  Population
# 0  1990          57
# 1  1995          58
# 2  2000          59
# 3  2005          60
# 4  2010          63
# 5  2015          65
# 6  2020          68

# %%
#creating data frame
df1=pd.DataFrame(Data,columns=["Year","Population"]) 
sns.lineplot(data=df1,x="Year",y="Population")
plt.title("Population vs Year", fontsize=16)
plt.xlabel("Year",fontsize=12)
plt.ylabel("Population in millions",fontsize=12)
plt.grid(color="grey",linestyle="--",linewidth=0.7)
plt.xticks(rotation=45)
plt.show()

# %%
#seaborn df_data
#creating line plot
df_date=df.groupby("OrderDate")["TotalPrice"].sum().to_frame().reset_index()
sns.lineplot(data=df_date,x="OrderDate",y="TotalPrice",marker="*")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Date and Time Types

# %%
date=pd.to_datetime("4th of july 2015")
date
# Out:
# Timestamp('2015-07-04 00:00:00')

# %%
date.strftime("%A")
# Out:
# 'Saturday'

# %%
date.strftime("%B")
# Out:
# 'July'

# %%
import datetime

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2022, 11, 19, 12, 44, 46, 682405)

# %%
x=datetime.datetime.now()
x
# Out:
# datetime.datetime(2022, 11, 19, 12, 45, 50, 141244)

# %%
print(x.year)
# Out:
# 2022

# %%
print(x.strftime("%A"))
# Out:
# Saturday

# %%
date+pd.to_timedelta(np.arange(10),"D")
# Out:
# DatetimeIndex(['2015-07-04', '2015-07-05', '2015-07-06', '2015-07-07',
#                '2015-07-08', '2015-07-09', '2015-07-10', '2015-07-11',
#                '2015-07-12', '2015-07-13'],
#               dtype='datetime64[ns]', freq=None)

# %%
date+pd.to_timedelta(np.arange(10),"m")
# Out:
# DatetimeIndex(['2015-07-04 00:00:00', '2015-07-04 00:01:00',
#                '2015-07-04 00:02:00', '2015-07-04 00:03:00',
#                '2015-07-04 00:04:00', '2015-07-04 00:05:00',
#                '2015-07-04 00:06:00', '2015-07-04 00:07:00',
#                '2015-07-04 00:08:00', '2015-07-04 00:09:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
datetime.datetime.now()
x=datetime.datetime.now()
x+pd.to_timedelta(np.arange(10),"m")
# Out:
# DatetimeIndex(['2022-11-19 12:57:21.142591', '2022-11-19 12:58:21.142591',
#                '2022-11-19 12:59:21.142591', '2022-11-19 13:00:21.142591',
#                '2022-11-19 13:01:21.142591', '2022-11-19 13:02:21.142591',
#                '2022-11-19 13:03:21.142591', '2022-11-19 13:04:21.142591',
#                '2022-11-19 13:05:21.142591', '2022-11-19 13:06:21.142591'],
#               dtype='datetime64[ns]', freq=None)

# %%
from dateutil import relativedelta

# %%
#creating date index
Index=pd.DatetimeIndex(["2022-10-13","2022-11-13","2023-10-13","2023-11-13"])
data=pd.Series([0,1,2,3],index=Index)
data
# Out:
# 2022-10-13    0
# 2022-11-13    1
# 2023-10-13    2
# 2023-11-13    3
# dtype: int64

# %%
data["2022-10-13":"2023-10-13"]
# Out:
# 2022-10-13    0
# 2022-11-13    1
# 2023-10-13    2
# dtype: int64

# %%
#pd.date_range()
pd.date_range("2022-10-13","2022-10-20")
# Out:
# DatetimeIndex(['2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#                '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2022-10-13",periods=8)
# Out:
# DatetimeIndex(['2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#                '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2022-10-13",periods=5)
# Out:
# DatetimeIndex(['2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#                '2022-10-17'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("2022-10-13",periods=5,freq="H")
# Out:
# DatetimeIndex(['2022-10-13 00:00:00', '2022-10-13 01:00:00',
#                '2022-10-13 02:00:00', '2022-10-13 03:00:00',
#                '2022-10-13 04:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range("2022-10-13",periods=5,freq="D")
#Y,MS,D
# Out:
# DatetimeIndex(['2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#                '2022-10-17'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# ## Data Cleasing

# %%
df3=pd.read_csv("/content/drive/MyDrive/Avado Training/Food samples.csv")
df3
# Out:
#    id  OrderDate Region         City  Category         Product  Quantity  \
# 0   1   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   2   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   3   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   4  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4   5        NaN   East          NaN       NaN             NaN       NaN
# 5   6  1/16/2020   East       Boston      Bars          Carrot      54.0
# 6   7  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 7   8  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4        NaN
# 5       1.77
# 6       3.49
# 7       1.77

# %%
#check for missing values
df3.isnull()
# Out:
#       id  OrderDate  Region   City  Category  Product  Quantity  UnitPrice
# 0  False      False   False  False     False    False     False      False
# 1  False      False   False  False     False    False     False      False
# 2  False      False   False  False     False    False     False      False
# 3  False      False   False  False     False    False     False      False
# 4  False       True   False   True      True     True      True       True
# 5  False      False   False  False     False    False     False      False
# 6  False      False   False  False     False    False     False      False
# 7  False      False   False  False     False    False     False      False

# %%
df3.isnull().sum()
# Out:
# id           0
# OrderDate    1
# Region       0
# City         1
# Category     1
# Product      1
# Quantity     1
# UnitPrice    1
# dtype: int64

# %%
#along the columns
df3.loc[df3.isnull().any(axis=1)]
# Out:
#    id OrderDate Region City Category Product  Quantity  UnitPrice
# 4   5       NaN   East  NaN      NaN     NaN       NaN        NaN

# %%
xdrop=df3.dropna().reset_index(drop=True)
xdrop
# Out:
#    id  OrderDate Region         City  Category         Product  Quantity  \
# 0   1   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   2   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   3   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   4  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4   6  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5   7  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6   8  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4       1.77
# 5       3.49
# 6       1.77

# %%
df3.dropna(subset=["OrderDate","City"])
# Out:
#    id  OrderDate Region         City  Category         Product  Quantity  \
# 0   1   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   2   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   3   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   4  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 5   6  1/16/2020   East       Boston      Bars          Carrot      54.0
# 6   7  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 7   8  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 5       1.77
# 6       3.49
# 7       1.77

# %%
df3
# Out:
#    id  OrderDate Region         City  Category         Product  Quantity  \
# 0   1   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   2   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   3   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   4  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4   5        NaN   East          NaN       NaN             NaN       NaN
# 5   6  1/16/2020   East       Boston      Bars          Carrot      54.0
# 6   7  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 7   8  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4        NaN
# 5       1.77
# 6       3.49
# 7       1.77

# %%
#drops all rows with empty cells
df3=df3.dropna().reset_index(drop=True)
df3
# Out:
#    id  OrderDate Region         City  Category         Product  Quantity  \
# 0   1   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   2   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   3   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3   4  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4   6  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5   7  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6   8  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4       1.77
# 5       3.49
# 6       1.77

# %%
#removing specific column
df3.drop(["id"],axis=1,inplace=True)

# %%
df3
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4       1.77
# 5       3.49
# 6       1.77

# %%
#dete rows

x3=df3.drop([2,3,4,5],axis=0)
x3
# Out:
#    OrderDate Region         City  Category      Product  Quantity  UnitPrice
# 0   1/1/2020   East       Boston      Bars       Carrot      33.0       1.77
# 1   1/4/2020   East       Boston  Crackers  Whole Wheat      87.0       3.49
# 6  1/22/2020   West  Los Angeles      Bars       Carrot      51.0       1.77

# %%
#creating a new column
df3["Total Price"]=df3["Quantity"]*df3['UnitPrice']
df3
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice  Total Price
# 0       1.77        58.41
# 1       3.49       303.63
# 2       1.87       108.46
# 3       1.87       153.34
# 4       1.77        95.58
# 5       3.49       520.01
# 6       1.77        90.27

# %%
x3=df3.drop([2,3,4,5],axis =0)#delete rows
x3
df3["Total Price"]=df3["Quantity"]*df3["UnitPrice"]#creating a new column
df3
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice  Total Price
# 0       1.77        58.41
# 1       3.49       303.63
# 2       1.87       108.46
# 3       1.87       153.34
# 4       1.77        95.58
# 5       3.49       520.01
# 6       1.77        90.27

# %%
df3=df3.drop(["Total Price"],axis =1)#deleting the last column
df3
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 0   1/1/2020   East       Boston      Bars          Carrot      33.0
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 4  1/16/2020   East       Boston      Bars          Carrot      54.0
# 5  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 6  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 0       1.77
# 1       3.49
# 2       1.87
# 3       1.87
# 4       1.77
# 5       3.49
# 6       1.77

# %%
df3.City.unique().tolist()#changing into a list
# Out:
# ['Boston', 'Los Angeles', 'New York']

# %%
df3.City.unique().tolist()
df3.sort_values(by=["UnitPrice"], ascending = False)#descending
sorteddf3=df3.sort_values(by=["UnitPrice"], ascending = False)#descending
sorteddf3
# Out:
#    OrderDate Region         City  Category         Product  Quantity  \
# 1   1/4/2020   East       Boston  Crackers     Whole Wheat      87.0
# 5  1/19/2020   East       Boston  Crackers     Whole Wheat     149.0
# 2   1/7/2020   West  Los Angeles   Cookies  Chocolate Chip      58.0
# 3  1/10/2020   East     New York   Cookies  Chocolate Chip      82.0
# 0   1/1/2020   East       Boston      Bars          Carrot      33.0
# 4  1/16/2020   East       Boston      Bars          Carrot      54.0
# 6  1/22/2020   West  Los Angeles      Bars          Carrot      51.0
#
#    UnitPrice
# 1       3.49
# 5       3.49
# 2       1.87
# 3       1.87
# 0       1.77
# 4       1.77
# 6       1.77

# %%
raw_data = {'ID': [1, 2, 3, 4, 5],
            'Name': ['Sara', 'Katie', 'David', 'Hazal', 'Georgie'],
            'Address': [42, 38, 36, 41, 35],
            'Salary': [33000, 45000, 65000, 95000, 35000]
            }

# %%
df1=pd.DataFrame(raw_data,columns=["ID","Name","Address","Salary"])
df1
# Out:
#    ID     Name  Address  Salary
# 0   1     Sara       42   33000
# 1   2    Katie       38   45000
# 2   3    David       36   65000
# 3   4    Hazal       41   95000
# 4   5  Georgie       35   35000

# %%
x["Salary Rank"]=x["Salary"].rank(ascending=False)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-93c0c49c33ba> in <module>
# ----> 1 x["Salary Rank"]=x["Salary"].rank(ascending=False)
#       2 print(x)
#
# TypeError: 'datetime.datetime' object is not subscriptable

# %%
x["Salary Rank"]=x["Salary"].rank(ascending=False)
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-177-93c0c49c33ba> in <module>
# ----> 1 x["Salary Rank"]=x["Salary"].rank(ascending=False)
#       2 print(x)
#
# TypeError: 'datetime.datetime' object is not subscriptable
